# %%
print("Niaj")
# Out:
# Niaj

# %%
prompt="What is your Name?"
print(len(prompt))
print("is" in prompt)
prompt=prompt.title()
print(prompt)
# Out:
# 18
# True
# What Is Your Name?

# %%
prompt="what is phitron ?"
tokens=prompt.split()
print(tokens)

sentence="-".join(tokens)
print(sentence)
# Out:
# ['what', 'is', 'phitron', '?']
# what-is-phitron-?

# %%
#Formatted String
name="Anon"
age=26
print(f"Her name is {name}.She is {age} years old")
# Out:
# Her name is Anon.She is 26 years old

# %% [markdown]
# List mutable

# %%
bajar=["alu", "kola" ,5, 2, 6.4, "mula",3]
new_bajar=bajar[0:5]
print(new_bajar)
# Out:
# ['alu', 'kola', 5, 2, 6.4]

# %% [markdown]
# Stack as List

# %%
stack=[]
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
stack.append(5)

print(stack.pop())
print(stack.pop())
print(stack.pop())
print(stack.pop())
print(stack.pop())
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
# List as Queue
queue=[]
queue.append(1)
queue.append(2)
queue.append(3)
queue.append(4)
queue.append(5)

print(queue.pop(0))
print(queue.pop(0))
print(queue.pop(0))
print(queue.pop(0))
print(queue.pop(0))
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Comprehension

# %%
random_list=[x for x in range(11) if x%2==0]
print(random_list)
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
fruits=["apple","orrange","lichi"]
capitalizefruits=[fol.upper() for fol in fruits ]
print(capitalizefruits)
# Out:
# ['APPLE', 'ORRANGE', 'LICHI']
