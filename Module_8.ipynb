# %%
class phone:
    category="Electronics"
apple=phone()
apple.category="Extra C"
samsung=phone()
honor=phone()
print(apple.category)
print(samsung.category)
print(honor.category)
# Out:
# Extra C
# Electronics
# Electronics

# %%
class phone:
    category="Electronics"

    def __init__(self,model,battery,camera,battery_percentage=100):
        self.model=model
        self.battery=battery
        self.camera=camera
        self.battery_percentage=battery_percentage
    def charge(self,hour):
        self.chare+=hour
    def capture(self,photo):
        if(self.battery_percentage)<=0:
            print("No charge")
        else:
            self.battery_percentage-=photo
            print(photo(f"Capture {model}"))
        
apple=phone("Iphone17",3000)
samsung=phone("S26",3500)
honor=phone("Honor200",5000)

apple.capture(10)
print(apple.battery_percentage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 23
#      15             print(photo(f"Capture {model}"))
#      17 # apple=phone("Iphone17",3000)
#      18 # samsung=phone("S26",3500)
#      19 # honor=phone("Honor200",5000)
#      20
#      21 # print(samsung.battery)
# ---> 23 apple.capture(10)
#      24 print(apple.battery_percentage)
#      25 # print(apple.battery_percentage)
#      26 # print(apple.photo
#
# Cell In[17], line 15, in phone.capture(self, photo)
#      13 else:
#      14     self.battery_percentage-=photo
# ---> 15     print(photo(f"Capture {model}"))
#
# NameError: name 'model' is not defined
