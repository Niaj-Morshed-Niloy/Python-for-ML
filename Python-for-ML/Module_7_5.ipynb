# %% [markdown]
# problem 1

# %%
a_friends={"Rahim","Karim","Sakib","Jamal"}
b_friends={"Sakib","Jamal","Rafiq","Nadim"}
mutual_friends=a_friends.intersection(b_friends)
print("Mutal friends:",mutual_friends)
Unique_to_A=a_friends-b_friends
print("Unique to A:",Unique_to_A)
Unique_to_B=b_friends-a_friends
print("Unique to B:",Unique_to_B)
print("Total unique friends:",len(a_friends.union(b_friends)))
# Out:
# Mutal friends: {'Sakib', 'Jamal'}
# Unique to A: {'Karim', 'Rahim'}
# Unique to B: {'Nadim', 'Rafiq'}
# Total unique friends: 6

# %% [markdown]
# Problem 2

# %%
students=[("Rafi",89),("Sumi",95),("Hasan",90),("Nila",75),("Anik",98)]
sort=sorted(students,key=lambda x:x[1], reverse=True)
top3=sort[:3]
print("Top 3 students:")
for name,marks in top3:
  print(name,"-",marks)
# Out:
# Top 3 students:
# Anik - 98
# Sumi - 95
# Hasan - 90

# %% [markdown]
# Problem-3

# %%
words=["sun","planet","moon","star","universe"]
length=list(filter(lambda x: len(x)>4 ,words))
print(length)
# Out:
# ['planet', 'universe']

# %% [markdown]
# Problem 4

# %%
nums=[1,2,3,4,5,6]
even=list(map(lambda x: x**2 ,filter(lambda x:x%2==0,nums)))
print(even)
# Out:
# [4, 16, 36]

# %% [markdown]
# problem 5

# %%
# Google colab

with open("./sample_data/data.txt","w+")as file:
  file.write("Learning python is fun")
  file.seek(0)
  print(file.read())

# %% [markdown]
# problem 6

# %%
# Google colab

from typing_extensions import final
try:
  file=open("./sample_data/story.txt","r")
except Exception as e:
  print(e)
else:
  print(file.readlines())
finally:
  print("StoP")
